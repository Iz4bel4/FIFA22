# %%
import pandas as pd
data_frame = pd.read_csv('FIFA22.csv')
data_frame
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %%
data_frame.shape
# Out:
# (16710, 65)

# %%
data_frame.values
# Out:
# array([[212198, 'Bruno Fernandes', 26, ..., 88.0, '€206.9M', 72.0],
#        [209658, 'L. Goretzka', 26, ..., 87.0, '€160.4M', 74.0],
#        [176580, 'L. Suárez', 34, ..., 88.0, '€91.2M', 42.0],
#        ...,
#        [241317, '21\xa0Xue Qinghao', 19, ..., 47.0, '€223K', 21.0],
#        [259646, 'A. Shaikh', 18, ..., 47.0, '€259K', 7.0],
#        [178453, '07\xa0A. Censori', 17, ..., 36.0, nan, nan]],
#       dtype=object)

# %%
df1 = pd.DataFrame(data, columns=['Name', 'Wage', 'Value'])

df1
# Out:
#                   Name   Wage    Value
# 0      Bruno Fernandes  €250K  €107.5M
# 1          L. Goretzka  €140K     €93M
# 2            L. Suárez  €135K   €44.5M
# 3         K. De Bruyne  €350K  €125.5M
# 4             M. Acuña   €45K     €37M
# ...                ...    ...      ...
# 16705    18 L. Clayton    €1K    €100K
# 16706         �. Dobre   €550    €180K
# 16707   21 Xue Qinghao   €700    €100K
# 16708        A. Shaikh   €500    €110K
# 16709    07 A. Censori     €0       €0
#
# [16710 rows x 3 columns]

# %%
df1 = pd.DataFrame(data, columns=['Name', 'Wage', 'Value'])
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0
wage = df1['Wage'].replace('[\€,]', '', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\€,]', '', regex=True).apply(value_to_float)

df1['Wage'] = wage
df1['Value'] = value
df1['difference'] = df1['Value'] - df1['Wage']
df1
# Out:
#                   Name      Wage        Value   difference
# 0      Bruno Fernandes  250000.0  107500000.0  107250000.0
# 1          L. Goretzka  140000.0   93000000.0   92860000.0
# 2            L. Suárez  135000.0   44500000.0   44365000.0
# 3         K. De Bruyne  350000.0  125500000.0  125150000.0
# 4             M. Acuña   45000.0   37000000.0   36955000.0
# ...                ...       ...          ...          ...
# 16705    18 L. Clayton    1000.0     100000.0      99000.0
# 16706         �. Dobre       0.0     180000.0     180000.0
# 16707   21 Xue Qinghao       0.0     100000.0     100000.0
# 16708        A. Shaikh       0.0     110000.0     110000.0
# 16709    07 A. Censori       0.0          0.0          0.0
#
# [16710 rows x 4 columns]

# %%
df1.sort_values('difference', ascending=False)
# Out:
#                 Name      Wage        Value   difference
# 82         K. Mbappé  230000.0  194000000.0  193770000.0
# 251       E. Haaland  110000.0  137500000.0  137390000.0
# 39           H. Kane  240000.0  129500000.0  129260000.0
# 64         Neymar Jr  270000.0  129000000.0  128730000.0
# 3       K. De Bruyne  350000.0  125500000.0  125150000.0
# ...              ...       ...          ...          ...
# 668    16 Zé Roberto   35000.0          0.0     -35000.0
# 11757   16 W. Samuel   40000.0          0.0     -40000.0
# 12888    16 M. Yepes   40000.0          0.0     -40000.0
# 3009   14 J. Zanetti   45000.0       1000.0     -44000.0
# 1770     14 R. Giggs   60000.0       1000.0     -59000.0
#
# [16710 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")]
)

p = figure(title="Soccer 2019", x_axis_label='Wage', y_axis_label='Value', min_width=700, min_height=700, tools=[TOOLTIPS])
p.circle('Wage', 'Value', size=10, source=df1)
show(p)
